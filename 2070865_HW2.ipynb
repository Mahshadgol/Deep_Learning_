# %% [markdown]
# #**Deep Learning Homework 2: *Optimize and Train Deep Models***
# ### MSc Computer Science, Data Science, Cybersecurity @UNIPD
# ### 2nd semester - 6 ECTS
# ### Prof. Alessandro Sperduti, Prof. Nicolò Navarin and Dr. Luca Pasa
# ---
# In this homework, we will explore how to develop a simple Deep Neural Network for a classification problem. We will learn how to use one of the most popular libraries for Deep Learning, namely [PyTorch 🔥](https://pytorch.org/). Then, we will see how to face a well known problem that is common during the training phase---overfitting on the training set. Finally, we will study how to perform a fair model selection.
#
# <u>Disclaimer</u>: PyTorch is a complex framework actively used by researcher and developers all over the word. It is highly customizable and there are many other packages build along it. The pourpouse of this and the next homeworks is not to go into all the details of its functionalities, but rather to give you an overview of its applications and understand its rationale. There are many good tutorials online and we suggest you to look at the official [Learn the Basics Tutorial](https://pytorch.org/tutorials/beginner/basics/intro.html), in particular if you are not familiar with other Deep Learning Frameworks.
#
# We hope that you will be able to use PyTorch by yourself for your future projects!
# ---
# ##**Important Instructions for Submissions:**
#
# Generally, in the homeworks, you will be either required to complete a part of Python code or to answer questions in text cells. Code and text cells where you are expected to write your answers have been marked by `%STARTCODE` and `%ENDCODE` or `%STARTEXT` and `%ENDTEXT` tags, respectively. Note that you should never change, move or remove these two tags, otherwise your answers will be __not__ valid. As you will see in this notebook, each cell that includes a `[TO COMPLETE]` part has been put between these placeholders.

# %% [markdown]
# ## Requirements

# %% [markdown]
# In this first exercise we will develop a deep feed forward neural network to perform text classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
# They've just released torch 2.0, but we will use the more stable torch=1.13 along with other supporting libriaries
# !pip3 install datasets skorch pandas~=1.5 torch~=1.13 torchinfo torchdata~=0.5 torchtext~=0.14 torchvision~=0.14 torchaudio~=0.13
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: skorch in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: pandas~=1.5 in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: torch~=1.13 in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.10/dist-packages (1.8.0)
# Requirement already satisfied: torchdata~=0.5 in /usr/local/lib/python3.10/dist-packages (0.5.1)
# Requirement already satisfied: torchtext~=0.14 in /usr/local/lib/python3.10/dist-packages (0.14.1)
# Requirement already satisfied: torchvision~=0.14 in /usr/local/lib/python3.10/dist-packages (0.14.1)
# Requirement already satisfied: torchaudio~=0.13 in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.14.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from skorch) (1.2.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from skorch) (1.10.1)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from skorch) (0.8.10)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas~=1.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas~=1.5) (2022.7.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch~=1.13) (4.5.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch~=1.13) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch~=1.13) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch~=1.13) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch~=1.13) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch~=1.13) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch~=1.13) (0.40.0)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from torchdata~=0.5) (1.26.15)
# Requirement already satisfied: portalocker>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchdata~=0.5) (2.7.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision~=0.14) (8.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas~=1.5) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->skorch) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->skorch) (3.1.0)

# %% [markdown]
# ##Imports

# %%
import torch
import torch.nn.functional as F
from torchinfo import summary
from torchtext.datasets import AG_NEWS
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch import nn
from sklearn.model_selection import GridSearchCV
from skorch import NeuralNetClassifier 
from skorch.helper import SliceDataset
import multiprocessing
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import logging
import os
from timeit import default_timer as timer

# %%
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 

print(f"{torch.__version__=}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"{device=}")
# !nvidia-smi --format=csv --query-gpu=index,name,driver_version,memory.total,memory.used,memory.free

# Set seed for reproducibility
torch.manual_seed(42)
rng = np.random.default_rng(seed=4242)
# Out:
# torch.__version__='1.13.1+cu117'
# device=device(type='cuda')
# index, name, driver_version, memory.total [MiB], memory.used [MiB], memory.free [MiB]
# 0, Tesla T4, 525.85.12, 15360 MiB, 3 MiB, 15098 MiB

# %% [markdown]
# #Data Loading and Preprocessing

# %% [markdown]
# ### Load Data: AG News Subset
#
# In this HW, we use the AG News Subset that is available in Torchtext Datasets. The AG's news topic classification dataset is constructed by choosing the 4 largest topic classes (1-World, 2-Sports, 3-Business, 4-Sci/Tech) from a larger news corpus. The total number of training samples is $120.000$ and testing $7.600$. For resource constraints, we will limit the number of training, validation and test samples to $10.000$, $1.000$ and $1.000$, respectively. Each sample contains both the title and an excerpt of the article, but in this exercise we will use only the excerpt as input.

# %%
train, test = AG_NEWS(root="dataset", split=('train', 'test'))
Tr, Ts = list(train), list(test)
rng.shuffle(Tr)
rng.shuffle(Ts)
len_train, len_val, len_test = 10000, 1000, 1000
train_data, val_data, test_data = Tr[:len_train], Ts[:len_val], Ts[len_val:len_val+len_test]

# %% [markdown]
# And have a look at one sample:

# %%
idx = 10
sample_label, sample_text = train_data[idx]
print(f"Text: {sample_text}")
print(f"Label: {sample_label}")
# Out:
# Text: Vancouver man is victim of shoddy FBI investigation: lawyer (Canadian Press) Canadian Press - VANCOUVER (CP) - A Vancouver man wanted by the U.S. for the 30-year-old murder of an American Indian Movement activist is being persecuted based on a faulty FBI investigation and the word of a troubled drug addict, says the lawyer defending his so-called partner in crime.
# Label: 1

# %% [markdown]
# ### Data Preprocessing
# We will go though the basic data processing building blocks for raw text string.
# Given a string, the first step is to tokenize the data to prepare it as input for the model. For this purpouse, we will use the basic Tokenizer of PyTorch. As you can see, it just normalizes the text, removes whitespaces and unsupported characters, and outputs a list:

# %%
tokenizer = get_tokenizer('basic_english')
print("Example: ", tokenizer("I am so HAPPY to study Deep Learning! #UNIPD #UniLIFE"))
# Out:
# Example:  ['i', 'am', 'so', 'happy', 'to', 'study', 'deep', 'learning', '!', '#unipd', '#unilife']

# %% [markdown]
# The AG News Subset dataset consists in news headlines---sequences of words. We have to encode each sample in a single tensor with a fixed number of elements, we will build a vocabulary of the headlines in our training set. In other words, we tokenize all the training set, and map each unique word into a number (a.k.a. index). This is necesseray as Neural Networks process numbers, so such vocabulary simply translates between readable words and numbers.

# %%
def create_tokens(dataset):
  for sample in dataset:
    yield tokenizer(sample[1])

# We limit our model to learn from the first 1000 most frequent tokens
vocab = build_vocab_from_iterator(create_tokens(train_data), specials=["<unk>"], max_tokens=1000) # <unk> is the index we use for specials characters ...
vocab.set_default_index(vocab["<unk>"]) # ... and as 0 the default values for tokens out of the vocabulary (OOV)
print(f"Our vocabulary is made of {len(vocab)} tokens-index pairs.")
# Out:
# Our vocabulary is made of 1000 tokens-index pairs.

# %% [markdown]
# This vocabulary was build from the training set. Let us see what it does on our example:

# %%
# Let us define some useful functions to handle tokens and labels
text_pipeline = lambda x: vocab(tokenizer(x)) # function to go from string -> tokens
label_pipeline = lambda x: int(x) - 1 # function to label starting form 0 for indexing

# %%
sample_tokenization = text_pipeline(sample_text)
sample_label_idx = label_pipeline(sample_label)
print(f"Samlpe headline text:\n {sample_text}")
print(f"Sample headline to tokens:\n {sample_tokenization}")
print(f"Label:\n {sample_label}")
print(f"Label index:\n {sample_label_idx}")
# Out:
# Samlpe headline text:
#  Vancouver man is victim of shoddy FBI investigation: lawyer (Canadian Press) Canadian Press - VANCOUVER (CP) - A Vancouver man wanted by the U.S. for the 30-year-old murder of an American Indian Movement activist is being persecuted based on a faulty FBI investigation and the word of a troubled drug addict, says the lawyer defending his so-called partner in crime.
# Sample headline to tokens:
#  [0, 415, 23, 0, 6, 0, 0, 963, 0, 13, 313, 262, 14, 313, 262, 15, 0, 13, 780, 14, 15, 5, 0, 415, 0, 24, 2, 51, 1, 9, 1, 11, 2, 0, 0, 6, 31, 159, 637, 0, 0, 23, 264, 0, 0, 10, 5, 0, 0, 963, 8, 2, 0, 6, 5, 0, 380, 0, 3, 82, 2, 0, 0, 34, 0, 0, 7, 0, 1]
# Label:
#  1
# Label index:
#  0

# %% [markdown]
# So each word is correctly mapped into a number, where most frequent words come first (see that the preposition "of", which is very frequent, gets translated to the number $6$). Notice also how "Vancouver" takes the default index value of $0$, meaning that is not frequent in the training set.
#
# Neural Netowrks (usually) take input of fixed size, but news aricles have different lenghts! To tackle this issue, one way is to resort to _multi-hot-encoding_ our dataset, means turning it into a tensor of $0$ and $1$. Concretely, this would mean for instance turning the sequence `[3, 5]` into a $1000$-dimensional vector (our vocabulary) that would be all zeros except for indices 3 and 5, which would be ones. The obtained input representation indicates which words are present (at least one time) in the sentence.

# %%
def multi_hot(token_list, n_cat=len(vocab)):
  encoded = [1 if i in token_list else 0 for i in range(n_cat)]
  return encoded

# %% [markdown]
# The next step is building a PyTorch `DataLoader`. Without going too much into the details, a `DataLoader` is the object one uses in the `for` loops when iterating over the data for training or inference. It has some additional benefits and pourpouses over iterating usual lists, such as multiprocessing, data transformation, sampling or shuffling. Don't worry too much for now, as we do this part for you.

# %%
class AGNewsDataset(Dataset):
  def __init__(self, dataset):
    super().__init__()
    self.dataset = dataset
  def __len__(self):
    return len(self.dataset)
  def __getitem__(self, idx):
    label, text = self.dataset[idx]
    lb = label_pipeline(label)
    txt = multi_hot(text_pipeline(text))
    lb, txt = torch.tensor(lb, dtype=torch.uint8, device=device), torch.tensor(txt, dtype=torch.float32, device=device)
    return lb, txt

# %%
train_dataset = AGNewsDataset(train_data)
val_dataset = AGNewsDataset(val_data)
test_dataset = AGNewsDataset(test_data)

# %%
batch_size = 256
dataloader_training = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
dataloader_validation = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
dataloader_test = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Exercise 2.1: Model Definition and Training
# We can now define the 3-layers feed forward model!
# In PyTorch we do that by subclassing `nn.Module`, and initialize the neural network layers in `__init__`. Every `nn.Module` subclass implements the operations on input data in the `forward` method.
#
# In detail, we created a `FeedforwardNetwork` class. The constructor takes three arguments: `input_dim` (an integer), which is the dimension of the input layer; `num_classes` (an integer), which is the number of output classes; and `hidden_layers_dim` (a list of integers), which is the dimension of the hidden layers in the network.
#
# In the constructor, the `nn.ModuleList() ` object is initialized to hold the layers of the network. If `hidden_layers_dim` is an empty list, then the network only consists of a single linear layer (from input to output). Otherwise, the network consists of multiple linear layers. The first layer goes from the input layer to the first hidden layer, and the subsequent hidden layers go from the previous hidden layer to the next hidden layer. The final output layer goes from the last hidden layer to the output layer.
#
# The `_init_weights` function is a helper function that initializes the weights of the linear layers in the network. It initializes the weights using a normal distribution with a mean of 0 and a standard deviation of 0.1, and sets the biases to zero. Notice that there exist other methods available in the `torch.nn.init` module to initialize layers' weights.
#
# The `forward` function defines the forward pass of the network. It first checks whether the network has only one layer (in which case it simply returns the output of that layer). Otherwise, it applies the `relu` activation function to the output of each hidden layer and passes the result to the next layer. Finally, it returns the output of the final layer. We don't apply the softmax function to the logits produced by the network as this will be done internally in the `CrossEntropyLoss` class, as documented [here](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html#torch.nn.CrossEntropyLoss).

# %%
class FeedforwardNetwork(nn.Module):
  
  def __init__(self, input_dim, num_classes, hidden_layers_dim=[]):
    super().__init__()
    self.layers = nn.ModuleList()
    if len(hidden_layers_dim) == 0:
      self.layers = self.layers.append(nn.Linear(input_dim, num_classes))
    else:
      for layer_idx in range(len(hidden_layers_dim)):
        if layer_idx == 0:  # first layer, from input to hidden
          self.layers = self.layers.append(nn.Linear(input_dim, hidden_layers_dim[layer_idx]))
        else:  # hidden layers, depending on the input
          self.layers = self.layers.append(nn.Linear(hidden_layers_dim[layer_idx-1], hidden_layers_dim[layer_idx]))
      self.layers = self.layers.append(nn.Linear(hidden_layers_dim[-1], num_classes))  # final output layer
    self.apply(self._init_weights)
    
  def _init_weights(self, module):
    if isinstance(module, nn.Linear):
        module.weight.data.normal_(mean=0.0, std=.1)
        if module.bias is not None:
            module.bias.data.zero_()
  
  def forward(self, x):
    if len(self.layers) == 1:
      return self.layers[0](x)
    else:
      for layer in self.layers[:-1]:
        x = F.relu(layer(x))
    return self.layers[-1](x)

# %%
# Now we prepare our model for this specific dataset and exercise
num_class = len(set([label for (label, text) in train_data]))
vocab_size = len(vocab)
EPOCHS = 40
lr = 1e-4
model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[64, 64]).to(device)
summary(model, (batch_size, vocab_size)) # Here is a nice summary of our model!
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# FeedforwardNetwork                       [256, 4]                  --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [256, 64]                 64,064
# │    └─Linear: 2-2                       [256, 64]                 4,160
# │    └─Linear: 2-3                       [256, 4]                  260
# ==========================================================================================
# Total params: 68,484
# Trainable params: 68,484
# Non-trainable params: 0
# Total mult-adds (M): 17.53
# ==========================================================================================
# Input size (MB): 1.02
# Forward/backward pass size (MB): 0.27
# Params size (MB): 0.27
# Estimated Total Size (MB): 1.57
# ==========================================================================================

# %%
# We need to defin our loss function (Cross Entropy for multiclass classification) and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# Finally, we can define the training procedure. In PyTorch there are few guidelines to follow to train a model. This time try on your own to understand what each line of code is doing, it will be required for the following HWs and exercises!

# %%
def train(model, optimizer, dataloader_train, dataloader_val, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      total_loss_train += loss
      loss.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %% [markdown]
# Let's train it!

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(model, optimizer, dataloader_training, dataloader_validation)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 28.64%, Loss: 1.37913513 ---------------- Val_Acc: 31.20%, Val_Loss: 1.37503576
# epoch: 2 -> Accuracy: 36.15%, Loss: 1.35842133 ---------------- Val_Acc: 37.60%, Val_Loss: 1.35475576
# epoch: 3 -> Accuracy: 43.21%, Loss: 1.33493888 ---------------- Val_Acc: 43.90%, Val_Loss: 1.32880688
# epoch: 4 -> Accuracy: 50.03%, Loss: 1.30309188 ---------------- Val_Acc: 51.20%, Val_Loss: 1.29239726
# epoch: 5 -> Accuracy: 55.87%, Loss: 1.25794160 ---------------- Val_Acc: 58.20%, Val_Loss: 1.24086499
# epoch: 6 -> Accuracy: 61.50%, Loss: 1.19568813 ---------------- Val_Acc: 63.90%, Val_Loss: 1.17141378
# epoch: 7 -> Accuracy: 66.12%, Loss: 1.11570477 ---------------- Val_Acc: 67.90%, Val_Loss: 1.08569670
# epoch: 8 -> Accuracy: 69.60%, Loss: 1.02212441 ---------------- Val_Acc: 71.50%, Val_Loss: 0.99064529
# epoch: 9 -> Accuracy: 72.73%, Loss: 0.92407846 ---------------- Val_Acc: 74.00%, Val_Loss: 0.89694917
# epoch: 10 -> Accuracy: 75.13%, Loss: 0.83106863 ---------------- Val_Acc: 76.30%, Val_Loss: 0.81376761
# epoch: 11 -> Accuracy: 77.04%, Loss: 0.75068587 ---------------- Val_Acc: 76.80%, Val_Loss: 0.74479467
# epoch: 12 -> Accuracy: 78.57%, Loss: 0.68470925 ---------------- Val_Acc: 77.80%, Val_Loss: 0.68973422
# epoch: 13 -> Accuracy: 79.98%, Loss: 0.63159096 ---------------- Val_Acc: 78.40%, Val_Loss: 0.64663410
# epoch: 14 -> Accuracy: 80.91%, Loss: 0.58883625 ---------------- Val_Acc: 79.30%, Val_Loss: 0.61304080
# epoch: 15 -> Accuracy: 81.83%, Loss: 0.55414236 ---------------- Val_Acc: 80.40%, Val_Loss: 0.58655113
# epoch: 16 -> Accuracy: 82.69%, Loss: 0.52551466 ---------------- Val_Acc: 80.70%, Val_Loss: 0.56524336
# epoch: 17 -> Accuracy: 83.39%, Loss: 0.50143409 ---------------- Val_Acc: 80.80%, Val_Loss: 0.54799080
# epoch: 18 -> Accuracy: 83.86%, Loss: 0.48084861 ---------------- Val_Acc: 81.00%, Val_Loss: 0.53393841
# epoch: 19 -> Accuracy: 84.46%, Loss: 0.46304965 ---------------- Val_Acc: 81.60%, Val_Loss: 0.52230698
# epoch: 20 -> Accuracy: 84.92%, Loss: 0.44744045 ---------------- Val_Acc: 82.20%, Val_Loss: 0.51253402
# epoch: 21 -> Accuracy: 85.32%, Loss: 0.43354765 ---------------- Val_Acc: 82.40%, Val_Loss: 0.50428164
# epoch: 22 -> Accuracy: 85.64%, Loss: 0.42106256 ---------------- Val_Acc: 82.60%, Val_Loss: 0.49730524
# epoch: 23 -> Accuracy: 86.00%, Loss: 0.40975380 ---------------- Val_Acc: 83.20%, Val_Loss: 0.49132779
# epoch: 24 -> Accuracy: 86.28%, Loss: 0.39941600 ---------------- Val_Acc: 83.30%, Val_Loss: 0.48617533
# epoch: 25 -> Accuracy: 86.61%, Loss: 0.38991123 ---------------- Val_Acc: 83.30%, Val_Loss: 0.48169667
# epoch: 26 -> Accuracy: 86.89%, Loss: 0.38111496 ---------------- Val_Acc: 83.70%, Val_Loss: 0.47779340
# epoch: 27 -> Accuracy: 87.18%, Loss: 0.37292975 ---------------- Val_Acc: 83.60%, Val_Loss: 0.47439647
# epoch: 28 -> Accuracy: 87.36%, Loss: 0.36526754 ---------------- Val_Acc: 83.40%, Val_Loss: 0.47145891
# epoch: 29 -> Accuracy: 87.59%, Loss: 0.35807091 ---------------- Val_Acc: 83.60%, Val_Loss: 0.46891040
# epoch: 30 -> Accuracy: 87.84%, Loss: 0.35127783 ---------------- Val_Acc: 83.70%, Val_Loss: 0.46671987
# epoch: 31 -> Accuracy: 88.06%, Loss: 0.34484786 ---------------- Val_Acc: 83.70%, Val_Loss: 0.46480390
# epoch: 32 -> Accuracy: 88.30%, Loss: 0.33873680 ---------------- Val_Acc: 83.90%, Val_Loss: 0.46315405
# epoch: 33 -> Accuracy: 88.51%, Loss: 0.33291170 ---------------- Val_Acc: 84.00%, Val_Loss: 0.46172655
# epoch: 34 -> Accuracy: 88.68%, Loss: 0.32734692 ---------------- Val_Acc: 84.00%, Val_Loss: 0.46047717
# epoch: 35 -> Accuracy: 88.77%, Loss: 0.32201678 ---------------- Val_Acc: 84.10%, Val_Loss: 0.45941666
# epoch: 36 -> Accuracy: 88.97%, Loss: 0.31690234 ---------------- Val_Acc: 84.50%, Val_Loss: 0.45856085
# epoch: 37 -> Accuracy: 89.13%, Loss: 0.31198615 ---------------- Val_Acc: 84.80%, Val_Loss: 0.45784882
# epoch: 38 -> Accuracy: 89.30%, Loss: 0.30725285 ---------------- Val_Acc: 84.60%, Val_Loss: 0.45727220
# epoch: 39 -> Accuracy: 89.49%, Loss: 0.30267859 ---------------- Val_Acc: 84.50%, Val_Loss: 0.45683849
# epoch: 40 -> Accuracy: 89.60%, Loss: 0.29826099 ---------------- Val_Acc: 84.50%, Val_Loss: 0.45652449
# Training time in second: 245.94519977300024

# %% [markdown]
# We can now plot these results:

# %%
def plot_learning_acc_and_loss(loss_tr, acc_tr, loss_val, acc_val):
    info = {'loss_training':loss_tr,'acc_trainig':acc_tr, 'loss_validation':loss_val, 'acc_validation':acc_val}
    df = pd.DataFrame(info)
    df.plot(figsize=(8, 10), subplots=[('acc_trainig', 'acc_validation'), ('loss_training','loss_validation')], grid=True)
    plt.xlabel("Epochs")
    plt.show()

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# ### [TO COMPLETE] Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set. By having a look at the previous code, compute the performances on the test set.

# %% [markdown]
# `%STARTCODE`

# %%
model.eval()
total_acc_test, total_count_test, n_batches_test, total_loss_test = 0, 0, 0, 0

#[TO COMPLETE]
for idx, (label, text) in enumerate(dataloader_test):
    logits = model(text)
    loss = criterion(logits, label)
    total_loss_test += loss
    total_acc_test += (logits.argmax(1) == label).sum().item()
    total_count_test += label.size(0)
    n_batches_test += 1

loss_test = total_loss_test/n_batches_test
accuracy_test = total_acc_test/total_count_test

print(f"Test Loss: {loss_test:.8f}", end=' ---------- ')
print(f"Test Accuracy: {100*accuracy_test:.4f}%")
# Out:
# Test Loss: 0.44434321 ---------- Test Accuracy: 84.3000%

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Explain why it is important to use test and validation, and why it is important to evaluate the model on the test set instead of the validation set. Finally, explain what is the usefulness of the validation set. Insert the discussion in the next cell.

# %% [markdown]
# `%STARTEXT`

# %% [markdown]
# Answer: **[TO COMLPETE]**
#
# It is important to use test and validation sets in neural networks because they help us evaluate the performance of our model on unseen data.
#
# The test set is important because it allows us to accurately evaluate how well the model performs on new data. By testing the model on this independent set, we can get a realistic idea of its actual performance and avoid overfitting to the validation set. But we cannot use validation set to evaluate model because the validation set has been seen by the model and it may have biased the model, where the set set does not have this problem as the model never have seen test data.
#
# The validation set is important for improving the model during training. It helps to choose the best hyperparameters and provides feedback on how well the model is doing. Last but not least, the validation set helps us make informed decisions and refine the model over time.

# %% [markdown]
# `%ENDTEXT`

# %% [markdown]
# # Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not much overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..

# %% [markdown]
# ## [TO COMPLETE] Overfitting Model
# In the next cell define a new model (similar to the previuos one) that overfits the training data; then plot the trend of the loss in training and validation set.

# %% [markdown]
# `%STARTCODE`

# %%
EPOCHS = 30 #[TO COMPLETE]
lr = 1e-2 #[TO COMPLETE]
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[64, 64]).to(device) #[TO COMPLETE]
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       64,064
# │    └─Linear: 2-2                       4,160
# │    └─Linear: 2-3                       260
# =================================================================
# Total params: 68,484
# Trainable params: 68,484
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train(overfit_model, optimizer, dataloader_training, dataloader_validation, EPOCHS = EPOCHS)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 75.10%, Loss: 0.66562307 ---------------- Val_Acc: 81.60%, Val_Loss: 0.49473900
# epoch: 2 -> Accuracy: 87.95%, Loss: 0.33107552 ---------------- Val_Acc: 83.90%, Val_Loss: 0.50084323
# epoch: 3 -> Accuracy: 91.46%, Loss: 0.24097815 ---------------- Val_Acc: 83.20%, Val_Loss: 0.56009793
# epoch: 4 -> Accuracy: 92.69%, Loss: 0.20008290 ---------------- Val_Acc: 80.60%, Val_Loss: 0.76600480
# epoch: 5 -> Accuracy: 92.66%, Loss: 0.19379966 ---------------- Val_Acc: 83.70%, Val_Loss: 0.65283936
# epoch: 6 -> Accuracy: 96.39%, Loss: 0.10406712 ---------------- Val_Acc: 83.50%, Val_Loss: 0.69180387
# epoch: 7 -> Accuracy: 97.81%, Loss: 0.06093691 ---------------- Val_Acc: 81.20%, Val_Loss: 0.90213221
# epoch: 8 -> Accuracy: 99.03%, Loss: 0.03134929 ---------------- Val_Acc: 83.20%, Val_Loss: 1.05479407
# epoch: 9 -> Accuracy: 99.49%, Loss: 0.01619192 ---------------- Val_Acc: 83.20%, Val_Loss: 1.11600757
# epoch: 10 -> Accuracy: 99.71%, Loss: 0.01075874 ---------------- Val_Acc: 83.50%, Val_Loss: 1.06372857
# epoch: 11 -> Accuracy: 99.88%, Loss: 0.00635778 ---------------- Val_Acc: 84.00%, Val_Loss: 1.12587738
# epoch: 12 -> Accuracy: 99.98%, Loss: 0.00208356 ---------------- Val_Acc: 84.00%, Val_Loss: 1.16092575
# epoch: 13 -> Accuracy: 99.98%, Loss: 0.00151941 ---------------- Val_Acc: 83.70%, Val_Loss: 1.17639828
# epoch: 14 -> Accuracy: 99.98%, Loss: 0.00082251 ---------------- Val_Acc: 83.90%, Val_Loss: 1.21631563
# epoch: 15 -> Accuracy: 99.99%, Loss: 0.00046180 ---------------- Val_Acc: 83.50%, Val_Loss: 1.24496472
# epoch: 16 -> Accuracy: 100.00%, Loss: 0.00026307 ---------------- Val_Acc: 83.50%, Val_Loss: 1.26810741
# epoch: 17 -> Accuracy: 100.00%, Loss: 0.00021861 ---------------- Val_Acc: 83.40%, Val_Loss: 1.28869295
# epoch: 18 -> Accuracy: 100.00%, Loss: 0.00018705 ---------------- Val_Acc: 83.40%, Val_Loss: 1.30709970
# epoch: 19 -> Accuracy: 100.00%, Loss: 0.00016311 ---------------- Val_Acc: 83.40%, Val_Loss: 1.32322860
# epoch: 20 -> Accuracy: 100.00%, Loss: 0.00014388 ---------------- Val_Acc: 83.40%, Val_Loss: 1.33875978
# epoch: 21 -> Accuracy: 100.00%, Loss: 0.00012833 ---------------- Val_Acc: 83.40%, Val_Loss: 1.35269630
# epoch: 22 -> Accuracy: 100.00%, Loss: 0.00011539 ---------------- Val_Acc: 83.40%, Val_Loss: 1.36621892
# epoch: 23 -> Accuracy: 100.00%, Loss: 0.00010449 ---------------- Val_Acc: 83.50%, Val_Loss: 1.37872100
# epoch: 24 -> Accuracy: 100.00%, Loss: 0.00009510 ---------------- Val_Acc: 83.50%, Val_Loss: 1.39069986
# epoch: 25 -> Accuracy: 100.00%, Loss: 0.00008703 ---------------- Val_Acc: 83.50%, Val_Loss: 1.40208745
# epoch: 26 -> Accuracy: 100.00%, Loss: 0.00008000 ---------------- Val_Acc: 83.50%, Val_Loss: 1.41273665
# epoch: 27 -> Accuracy: 100.00%, Loss: 0.00007381 ---------------- Val_Acc: 83.50%, Val_Loss: 1.42319095
# epoch: 28 -> Accuracy: 100.00%, Loss: 0.00006837 ---------------- Val_Acc: 83.50%, Val_Loss: 1.43292332
# epoch: 29 -> Accuracy: 100.00%, Loss: 0.00006346 ---------------- Val_Acc: 83.50%, Val_Loss: 1.44268262
# epoch: 30 -> Accuracy: 100.00%, Loss: 0.00005909 ---------------- Val_Acc: 83.50%, Val_Loss: 1.45185089
# Training time in second: 168.56595314199967

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Exercise 2.3: $L^1$- and $L^2$-regularization
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \lambda L^p(\theta)
# $$
# where $\lambda$ is a hyperparameter that weighs the relative contribution of the norm penalty $L^p$ on a lernable parameter vector $\theta$:
# $$
#  L^p(\theta)=||\theta||_p=\left(\sum_i |\theta_i|^p\right)^{1/p}
# $$

# %% [markdown]
# In the following blocks you should implement both the $L^1$ and $L^2$ regularization for the overfitting model.
#
# **Disclaimer**: you can implement norms either from scratch (i.e. using simple math operators) or using `torch.linalg` methods, but **not** using implementations embedded in Torch optimizers.

# %% [markdown]
# ### [TO COMPLETE] $L^1$ Regularization

# %% [markdown]
# `%STARTCODE`

# %%
def train_L1(model, optimizer, dataloader_train, dataloader_val, l1_lambda=0.5, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      ##########################################################
      #[TO COMPLETE]
      regularizer = 0
      for W in model.parameters():
        regularizer += torch.linalg.norm(W, ord = 1)
      loss_with_l1 = loss + l1_lambda * regularizer
      ##########################################################
      total_loss_train += loss
      loss_with_l1.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_L1(overfit_model, optimizer, dataloader_training, dataloader_validation, l1_lambda=0.001)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 28.30%, Loss: 1.38085210 ---------------- Val_Acc: 34.00%, Val_Loss: 1.35451400
# epoch: 2 -> Accuracy: 38.81%, Loss: 1.33354712 ---------------- Val_Acc: 44.00%, Val_Loss: 1.31000125
# epoch: 3 -> Accuracy: 48.76%, Loss: 1.26751077 ---------------- Val_Acc: 55.30%, Val_Loss: 1.22951543
# epoch: 4 -> Accuracy: 60.29%, Loss: 1.15448201 ---------------- Val_Acc: 63.20%, Val_Loss: 1.09856319
# epoch: 5 -> Accuracy: 69.82%, Loss: 0.99209750 ---------------- Val_Acc: 70.50%, Val_Loss: 0.93053126
# epoch: 6 -> Accuracy: 75.61%, Loss: 0.81165612 ---------------- Val_Acc: 72.60%, Val_Loss: 0.77628815
# epoch: 7 -> Accuracy: 79.10%, Loss: 0.66754025 ---------------- Val_Acc: 75.50%, Val_Loss: 0.67413437
# epoch: 8 -> Accuracy: 81.29%, Loss: 0.57293671 ---------------- Val_Acc: 77.90%, Val_Loss: 0.61240470
# epoch: 9 -> Accuracy: 83.00%, Loss: 0.51052511 ---------------- Val_Acc: 79.60%, Val_Loss: 0.57345617
# epoch: 10 -> Accuracy: 84.34%, Loss: 0.46580583 ---------------- Val_Acc: 80.80%, Val_Loss: 0.54730499
# epoch: 11 -> Accuracy: 85.52%, Loss: 0.43108892 ---------------- Val_Acc: 81.30%, Val_Loss: 0.52901155
# epoch: 12 -> Accuracy: 86.41%, Loss: 0.40275979 ---------------- Val_Acc: 82.00%, Val_Loss: 0.51582384
# epoch: 13 -> Accuracy: 87.29%, Loss: 0.37865007 ---------------- Val_Acc: 82.70%, Val_Loss: 0.50621915
# epoch: 14 -> Accuracy: 88.09%, Loss: 0.35762540 ---------------- Val_Acc: 82.70%, Val_Loss: 0.49922520
# epoch: 15 -> Accuracy: 88.71%, Loss: 0.33884063 ---------------- Val_Acc: 83.10%, Val_Loss: 0.49436748
# epoch: 16 -> Accuracy: 89.35%, Loss: 0.32177919 ---------------- Val_Acc: 83.20%, Val_Loss: 0.49102440
# epoch: 17 -> Accuracy: 89.81%, Loss: 0.30609536 ---------------- Val_Acc: 83.20%, Val_Loss: 0.48900965
# epoch: 18 -> Accuracy: 90.14%, Loss: 0.29152462 ---------------- Val_Acc: 83.40%, Val_Loss: 0.48802841
# epoch: 19 -> Accuracy: 90.73%, Loss: 0.27784419 ---------------- Val_Acc: 83.40%, Val_Loss: 0.48799902
# epoch: 20 -> Accuracy: 91.31%, Loss: 0.26491648 ---------------- Val_Acc: 83.50%, Val_Loss: 0.48876026
# epoch: 21 -> Accuracy: 91.80%, Loss: 0.25257790 ---------------- Val_Acc: 83.50%, Val_Loss: 0.49013436
# epoch: 22 -> Accuracy: 92.23%, Loss: 0.24075262 ---------------- Val_Acc: 83.50%, Val_Loss: 0.49229905
# epoch: 23 -> Accuracy: 92.65%, Loss: 0.22933765 ---------------- Val_Acc: 83.50%, Val_Loss: 0.49500340
# epoch: 24 -> Accuracy: 93.15%, Loss: 0.21830177 ---------------- Val_Acc: 83.50%, Val_Loss: 0.49838024
# epoch: 25 -> Accuracy: 93.66%, Loss: 0.20763572 ---------------- Val_Acc: 83.60%, Val_Loss: 0.50227857
# epoch: 26 -> Accuracy: 93.93%, Loss: 0.19726564 ---------------- Val_Acc: 83.60%, Val_Loss: 0.50658941
# epoch: 27 -> Accuracy: 94.31%, Loss: 0.18719997 ---------------- Val_Acc: 83.40%, Val_Loss: 0.51133776
# epoch: 28 -> Accuracy: 94.68%, Loss: 0.17743030 ---------------- Val_Acc: 83.30%, Val_Loss: 0.51659834
# epoch: 29 -> Accuracy: 95.17%, Loss: 0.16793816 ---------------- Val_Acc: 83.30%, Val_Loss: 0.52217156
# epoch: 30 -> Accuracy: 95.60%, Loss: 0.15869524 ---------------- Val_Acc: 83.20%, Val_Loss: 0.52835757
# Training time in second: 170.0869904279989

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# ### [TO COMPLETE] $L^2$ Regularization

# %% [markdown]
# `%STARTCODE`

# %%
def train_L2(model, optimizer, dataloader_train, dataloader_val, l2_lambda=0.5, EPOCHS=EPOCHS):
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      ##########################################################
      #[TO COMPLETE]
      regularizer = 0
      for W in model.parameters():
        regularizer += torch.linalg.norm(W, ord = 2)
      loss_with_l2 = loss + l2_lambda * regularizer
      ##########################################################
      total_loss_train += loss
      loss_with_l2.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_L2(overfit_model, optimizer, dataloader_training, dataloader_validation, l2_lambda=0.01)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 32.00%, Loss: 1.36038339 ---------------- Val_Acc: 41.00%, Val_Loss: 1.32389772
# epoch: 2 -> Accuracy: 48.43%, Loss: 1.27431953 ---------------- Val_Acc: 53.00%, Val_Loss: 1.23485172
# epoch: 3 -> Accuracy: 59.71%, Loss: 1.15776515 ---------------- Val_Acc: 62.40%, Val_Loss: 1.10384786
# epoch: 4 -> Accuracy: 68.02%, Loss: 1.00291800 ---------------- Val_Acc: 69.30%, Val_Loss: 0.94460034
# epoch: 5 -> Accuracy: 73.49%, Loss: 0.83693230 ---------------- Val_Acc: 73.10%, Val_Loss: 0.79884553
# epoch: 6 -> Accuracy: 76.72%, Loss: 0.69940186 ---------------- Val_Acc: 75.30%, Val_Loss: 0.69498801
# epoch: 7 -> Accuracy: 79.48%, Loss: 0.60253590 ---------------- Val_Acc: 77.60%, Val_Loss: 0.62885606
# epoch: 8 -> Accuracy: 81.40%, Loss: 0.53642106 ---------------- Val_Acc: 78.30%, Val_Loss: 0.58702701
# epoch: 9 -> Accuracy: 82.88%, Loss: 0.48858866 ---------------- Val_Acc: 80.30%, Val_Loss: 0.55902684
# epoch: 10 -> Accuracy: 84.08%, Loss: 0.45150533 ---------------- Val_Acc: 81.10%, Val_Loss: 0.53923666
# epoch: 11 -> Accuracy: 85.12%, Loss: 0.42125520 ---------------- Val_Acc: 81.80%, Val_Loss: 0.52455348
# epoch: 12 -> Accuracy: 86.02%, Loss: 0.39554369 ---------------- Val_Acc: 82.10%, Val_Loss: 0.51349032
# epoch: 13 -> Accuracy: 86.83%, Loss: 0.37314412 ---------------- Val_Acc: 82.40%, Val_Loss: 0.50506598
# epoch: 14 -> Accuracy: 87.65%, Loss: 0.35321543 ---------------- Val_Acc: 82.60%, Val_Loss: 0.49870154
# epoch: 15 -> Accuracy: 88.38%, Loss: 0.33513770 ---------------- Val_Acc: 82.70%, Val_Loss: 0.49388999
# epoch: 16 -> Accuracy: 89.07%, Loss: 0.31855571 ---------------- Val_Acc: 82.90%, Val_Loss: 0.49026036
# epoch: 17 -> Accuracy: 89.70%, Loss: 0.30318615 ---------------- Val_Acc: 83.20%, Val_Loss: 0.48772287
# epoch: 18 -> Accuracy: 90.34%, Loss: 0.28881910 ---------------- Val_Acc: 83.20%, Val_Loss: 0.48599169
# epoch: 19 -> Accuracy: 90.99%, Loss: 0.27529213 ---------------- Val_Acc: 83.20%, Val_Loss: 0.48497590
# epoch: 20 -> Accuracy: 91.57%, Loss: 0.26245984 ---------------- Val_Acc: 83.50%, Val_Loss: 0.48466060
# epoch: 21 -> Accuracy: 92.10%, Loss: 0.25022313 ---------------- Val_Acc: 83.40%, Val_Loss: 0.48482421
# epoch: 22 -> Accuracy: 92.49%, Loss: 0.23847631 ---------------- Val_Acc: 83.70%, Val_Loss: 0.48552305
# epoch: 23 -> Accuracy: 93.01%, Loss: 0.22717774 ---------------- Val_Acc: 83.80%, Val_Loss: 0.48684850
# epoch: 24 -> Accuracy: 93.47%, Loss: 0.21628737 ---------------- Val_Acc: 83.60%, Val_Loss: 0.48857301
# epoch: 25 -> Accuracy: 93.91%, Loss: 0.20575877 ---------------- Val_Acc: 83.70%, Val_Loss: 0.49053806
# epoch: 26 -> Accuracy: 94.38%, Loss: 0.19558010 ---------------- Val_Acc: 83.90%, Val_Loss: 0.49301714
# epoch: 27 -> Accuracy: 94.84%, Loss: 0.18569069 ---------------- Val_Acc: 84.00%, Val_Loss: 0.49605703
# epoch: 28 -> Accuracy: 95.21%, Loss: 0.17609958 ---------------- Val_Acc: 83.90%, Val_Loss: 0.49911419
# epoch: 29 -> Accuracy: 95.52%, Loss: 0.16682251 ---------------- Val_Acc: 84.00%, Val_Loss: 0.50270981
# epoch: 30 -> Accuracy: 95.81%, Loss: 0.15785192 ---------------- Val_Acc: 83.90%, Val_Loss: 0.50642598
# epoch: 31 -> Accuracy: 96.20%, Loss: 0.14919673 ---------------- Val_Acc: 84.00%, Val_Loss: 0.51039547
# epoch: 32 -> Accuracy: 96.51%, Loss: 0.14086436 ---------------- Val_Acc: 83.90%, Val_Loss: 0.51469648
# epoch: 33 -> Accuracy: 96.87%, Loss: 0.13283557 ---------------- Val_Acc: 83.80%, Val_Loss: 0.51918471
# epoch: 34 -> Accuracy: 97.24%, Loss: 0.12512708 ---------------- Val_Acc: 83.80%, Val_Loss: 0.52381814
# epoch: 35 -> Accuracy: 97.50%, Loss: 0.11772486 ---------------- Val_Acc: 83.70%, Val_Loss: 0.52871674
# epoch: 36 -> Accuracy: 97.82%, Loss: 0.11062220 ---------------- Val_Acc: 83.90%, Val_Loss: 0.53375036
# epoch: 37 -> Accuracy: 97.99%, Loss: 0.10385139 ---------------- Val_Acc: 84.10%, Val_Loss: 0.53892905
# epoch: 38 -> Accuracy: 98.18%, Loss: 0.09739460 ---------------- Val_Acc: 84.00%, Val_Loss: 0.54428011
# epoch: 39 -> Accuracy: 98.37%, Loss: 0.09123574 ---------------- Val_Acc: 84.10%, Val_Loss: 0.54968405
# epoch: 40 -> Accuracy: 98.54%, Loss: 0.08538508 ---------------- Val_Acc: 83.90%, Val_Loss: 0.55525833
# Training time in second: 301.19049667599984

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Exercise 2.4: Early Stopping
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (a.k.a. the "patience" or "tolerance" hyper-parameter), it stops the training phase.
#
# To implement it in PyTorch, we define a simple classes that does this job.

# %%
class EarlyStopping:
    def __init__(self, tolerance, min_delta):
        self.tolerance = tolerance
        self.min_delta = min_delta
        self.counter = 0
        self.early_stop = False

    def __call__(self, train_loss, validation_loss):
        if (validation_loss - train_loss) > self.min_delta:
            self.counter +=1
            if self.counter >= self.tolerance:  
                self.early_stop = True

# %% [markdown]
# ## **[TO COMPLETE]**: Define training procedure
# Define a training procedure with Early Stopping and check its performances.

# %% [markdown]
# `%STARTCODE`

# %%
def train_early_stop(model, optimizer, dataloader_train, dataloader_val, EPOCHS=EPOCHS):
  ###########################################################
  # instantiate an object of the EarlyStopping class 
  #[TO COMPLETE]
  early_stop = EarlyStopping(tolerance=5, min_delta=0.1)
  ###########################################################
  loss_train, loss_val = [], []
  acc_train, acc_val = [], []
  for epoch in range(EPOCHS):

    model.train()
    total_acc_train, total_count_train, n_train_batches, total_loss_train = 0, 0, 0, 0
    for idx, (label, text) in enumerate(dataloader_train):
      optimizer.zero_grad()
      logits = model(text)
      loss = criterion(logits, label)
      total_loss_train += loss
      loss.backward()
      optimizer.step()

      total_acc_train += (logits.argmax(1) == label).sum().item()
      total_count_train += label.size(0)
      n_train_batches += 1

    avg_loss_train = total_loss_train/n_train_batches
    loss_train.append(avg_loss_train.item())
    accuracy_train = total_acc_train/total_count_train
    acc_train.append(accuracy_train)
    
    total_acc_val, total_count_val, n_val_batches, total_loss_val = 0, 0, 0, 0
    with torch.no_grad():
        model.eval()
        for idx, (label, text) in enumerate(dataloader_val):
            logits = model(text)
            loss = criterion(logits, label)
            total_loss_val += loss
            total_acc_val += (logits.argmax(1) == label).sum().item()
            total_count_val += label.size(0)
            n_val_batches += 1
    avg_loss_val = total_loss_val/n_val_batches
    loss_val.append(avg_loss_val.item())
    accuracy_val = total_acc_val/total_count_val
    acc_val.append(accuracy_val) 
    if epoch % 1 == 0:
      print(f"epoch: {epoch+1} -> Accuracy: {100*accuracy_train:.2f}%, Loss: {avg_loss_train:.8f}",end=" ---------------- ")
      print(f"Val_Acc: {100*accuracy_val:.2f}%, Val_Loss: {avg_loss_val:.8f}")
    ############################################################
    # Use the EarlyStopping object
    #[TO COMPLETE]
    early_stop(avg_loss_train, avg_loss_val)
    if early_stop.early_stop: 
      # print("EARLY STOP REACHED!!!!")
      break
    ############################################################
  return loss_train, acc_train, loss_val, acc_val

# %%
EPOCHS = 40
lr = 1e-4
overfit_model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[256, 128, 64]).to(device)
optimizer = torch.optim.Adam(overfit_model.parameters(), lr=lr)
summary(overfit_model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# FeedforwardNetwork                       --
# ├─ModuleList: 1-1                        --
# │    └─Linear: 2-1                       256,256
# │    └─Linear: 2-2                       32,896
# │    └─Linear: 2-3                       8,256
# │    └─Linear: 2-4                       260
# =================================================================
# Total params: 297,668
# Trainable params: 297,668
# Non-trainable params: 0
# =================================================================

# %%
start = timer()
loss_train, accuracy_train, loss_val, accuracy_val = train_early_stop(overfit_model, optimizer, dataloader_training, dataloader_validation)
end = timer()
print(f"Training time in second: {(end - start)}")
# Out:
# epoch: 1 -> Accuracy: 32.17%, Loss: 1.36296773 ---------------- Val_Acc: 38.00%, Val_Loss: 1.33221972
# epoch: 2 -> Accuracy: 46.26%, Loss: 1.28697932 ---------------- Val_Acc: 51.10%, Val_Loss: 1.25309193
# epoch: 3 -> Accuracy: 58.44%, Loss: 1.18514919 ---------------- Val_Acc: 60.80%, Val_Loss: 1.13796163
# epoch: 4 -> Accuracy: 66.98%, Loss: 1.04129517 ---------------- Val_Acc: 68.10%, Val_Loss: 0.98232436
# epoch: 5 -> Accuracy: 73.02%, Loss: 0.87135422 ---------------- Val_Acc: 72.20%, Val_Loss: 0.82631016
# epoch: 6 -> Accuracy: 76.80%, Loss: 0.72245878 ---------------- Val_Acc: 74.90%, Val_Loss: 0.70914775
# epoch: 7 -> Accuracy: 79.47%, Loss: 0.61682671 ---------------- Val_Acc: 77.80%, Val_Loss: 0.63406926
# epoch: 8 -> Accuracy: 81.45%, Loss: 0.54559177 ---------------- Val_Acc: 78.80%, Val_Loss: 0.58616996
# epoch: 9 -> Accuracy: 83.05%, Loss: 0.49487242 ---------------- Val_Acc: 79.80%, Val_Loss: 0.55457062
# epoch: 10 -> Accuracy: 84.27%, Loss: 0.45630223 ---------------- Val_Acc: 81.10%, Val_Loss: 0.53270614
# epoch: 11 -> Accuracy: 85.32%, Loss: 0.42520729 ---------------- Val_Acc: 81.60%, Val_Loss: 0.51720178
# epoch: 12 -> Accuracy: 86.35%, Loss: 0.39902002 ---------------- Val_Acc: 82.00%, Val_Loss: 0.50605071
# epoch: 13 -> Accuracy: 87.19%, Loss: 0.37622333 ---------------- Val_Acc: 82.10%, Val_Loss: 0.49779463
# epoch: 14 -> Accuracy: 87.89%, Loss: 0.35587284 ---------------- Val_Acc: 82.40%, Val_Loss: 0.49195635
# epoch: 15 -> Accuracy: 88.45%, Loss: 0.33738837 ---------------- Val_Acc: 82.30%, Val_Loss: 0.48768556
# epoch: 16 -> Accuracy: 89.11%, Loss: 0.32041252 ---------------- Val_Acc: 82.20%, Val_Loss: 0.48467070
# Training time in second: 92.11919199299973

# %%
plot_learning_acc_and_loss(loss_train, accuracy_train, loss_val, accuracy_val)

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# # Model Selection
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit (the network weights). The aim of model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learning rate:

# %%
learning_rates = [1e-5, 1e-4, 1e-3]

# %%
stack = []
for lr in learning_rates:
  print(f"Learning Rate: {lr}")
  model = FeedforwardNetwork(vocab_size, num_class, hidden_layers_dim=[128, 64]).to(device)
  optimizer = torch.optim.Adam(model.parameters(), lr=lr)
  stack.append(train(model, optimizer, dataloader_training, dataloader_validation, EPOCHS=15))
  print("-"*50)
# Out:
# Learning Rate: 1e-05
# epoch: 1 -> Accuracy: 28.17%, Loss: 1.38030696 ---------------- Val_Acc: 29.10%, Val_Loss: 1.38279080
# epoch: 2 -> Accuracy: 29.17%, Loss: 1.37627494 ---------------- Val_Acc: 30.20%, Val_Loss: 1.37915766
# epoch: 3 -> Accuracy: 30.16%, Loss: 1.37241971 ---------------- Val_Acc: 30.50%, Val_Loss: 1.37556946
# epoch: 4 -> Accuracy: 31.13%, Loss: 1.36860836 ---------------- Val_Acc: 31.30%, Val_Loss: 1.37200415
# epoch: 5 -> Accuracy: 31.95%, Loss: 1.36481392 ---------------- Val_Acc: 32.10%, Val_Loss: 1.36844015
# epoch: 6 -> Accuracy: 32.90%, Loss: 1.36101449 ---------------- Val_Acc: 33.40%, Val_Loss: 1.36486173
# epoch: 7 -> Accuracy: 34.09%, Loss: 1.35719311 ---------------- Val_Acc: 34.70%, Val_Loss: 1.36126280
# epoch: 8 -> Accuracy: 34.92%, Loss: 1.35332823 ---------------- Val_Acc: 35.50%, Val_Loss: 1.35762000
# epoch: 9 -> Accuracy: 36.02%, Loss: 1.34941232 ---------------- Val_Acc: 35.90%, Val_Loss: 1.35392523
# epoch: 10 -> Accuracy: 36.99%, Loss: 1.34542978 ---------------- Val_Acc: 36.70%, Val_Loss: 1.35016251
# epoch: 11 -> Accuracy: 38.10%, Loss: 1.34136736 ---------------- Val_Acc: 38.20%, Val_Loss: 1.34632218
# epoch: 12 -> Accuracy: 38.98%, Loss: 1.33722544 ---------------- Val_Acc: 39.30%, Val_Loss: 1.34238791
# epoch: 13 -> Accuracy: 40.25%, Loss: 1.33299005 ---------------- Val_Acc: 39.80%, Val_Loss: 1.33836508
# epoch: 14 -> Accuracy: 41.29%, Loss: 1.32864237 ---------------- Val_Acc: 40.60%, Val_Loss: 1.33422315
# epoch: 15 -> Accuracy: 42.22%, Loss: 1.32418060 ---------------- Val_Acc: 41.60%, Val_Loss: 1.32997465
# --------------------------------------------------
# Learning Rate: 0.0001
# epoch: 1 -> Accuracy: 28.53%, Loss: 1.39971638 ---------------- Val_Acc: 31.70%, Val_Loss: 1.37577462
# epoch: 2 -> Accuracy: 36.94%, Loss: 1.34724331 ---------------- Val_Acc: 40.10%, Val_Loss: 1.33521116
# epoch: 3 -> Accuracy: 45.92%, Loss: 1.30273378 ---------------- Val_Acc: 47.90%, Val_Loss: 1.28908885
# epoch: 4 -> Accuracy: 53.61%, Loss: 1.24739110 ---------------- Val_Acc: 55.90%, Val_Loss: 1.22838414
# epoch: 5 -> Accuracy: 60.94%, Loss: 1.17527008 ---------------- Val_Acc: 61.80%, Val_Loss: 1.15130258
# epoch: 6 -> Accuracy: 66.80%, Loss: 1.08763063 ---------------- Val_Acc: 67.70%, Val_Loss: 1.06160164
# epoch: 7 -> Accuracy: 71.25%, Loss: 0.99037343 ---------------- Val_Acc: 71.70%, Val_Loss: 0.96629614
# epoch: 8 -> Accuracy: 74.57%, Loss: 0.89156866 ---------------- Val_Acc: 74.30%, Val_Loss: 0.87470877
# epoch: 9 -> Accuracy: 77.17%, Loss: 0.79931074 ---------------- Val_Acc: 75.90%, Val_Loss: 0.79358834
# epoch: 10 -> Accuracy: 78.79%, Loss: 0.71905297 ---------------- Val_Acc: 77.60%, Val_Loss: 0.72675729
# epoch: 11 -> Accuracy: 80.25%, Loss: 0.65269125 ---------------- Val_Acc: 78.70%, Val_Loss: 0.67433894
# epoch: 12 -> Accuracy: 81.55%, Loss: 0.59920532 ---------------- Val_Acc: 79.40%, Val_Loss: 0.63366842
# epoch: 13 -> Accuracy: 82.74%, Loss: 0.55636042 ---------------- Val_Acc: 79.60%, Val_Loss: 0.60224968
# epoch: 14 -> Accuracy: 83.46%, Loss: 0.52164739 ---------------- Val_Acc: 80.10%, Val_Loss: 0.57791626
# epoch: 15 -> Accuracy: 84.16%, Loss: 0.49307808 ---------------- Val_Acc: 80.50%, Val_Loss: 0.55874813
# --------------------------------------------------
# Learning Rate: 0.001
# epoch: 1 -> Accuracy: 52.91%, Loss: 1.18562937 ---------------- Val_Acc: 73.00%, Val_Loss: 0.84643394
# epoch: 2 -> Accuracy: 80.01%, Loss: 0.59566778 ---------------- Val_Acc: 79.70%, Val_Loss: 0.53099710
# epoch: 3 -> Accuracy: 85.70%, Loss: 0.40192840 ---------------- Val_Acc: 81.60%, Val_Loss: 0.48569763
# epoch: 4 -> Accuracy: 88.67%, Loss: 0.32649156 ---------------- Val_Acc: 82.70%, Val_Loss: 0.47051662
# epoch: 5 -> Accuracy: 90.84%, Loss: 0.27407897 ---------------- Val_Acc: 84.10%, Val_Loss: 0.47305354
# epoch: 6 -> Accuracy: 92.41%, Loss: 0.23089479 ---------------- Val_Acc: 83.90%, Val_Loss: 0.48569173
# epoch: 7 -> Accuracy: 94.15%, Loss: 0.19227497 ---------------- Val_Acc: 84.20%, Val_Loss: 0.50371957
# epoch: 8 -> Accuracy: 95.46%, Loss: 0.15693176 ---------------- Val_Acc: 83.50%, Val_Loss: 0.52683318
# epoch: 9 -> Accuracy: 96.85%, Loss: 0.12483527 ---------------- Val_Acc: 82.80%, Val_Loss: 0.55609798
# epoch: 10 -> Accuracy: 97.87%, Loss: 0.09635660 ---------------- Val_Acc: 82.50%, Val_Loss: 0.59121501
# epoch: 11 -> Accuracy: 98.66%, Loss: 0.07266222 ---------------- Val_Acc: 82.30%, Val_Loss: 0.62975651
# epoch: 12 -> Accuracy: 99.25%, Loss: 0.05481909 ---------------- Val_Acc: 82.50%, Val_Loss: 0.66543424
# epoch: 13 -> Accuracy: 99.55%, Loss: 0.04338714 ---------------- Val_Acc: 82.50%, Val_Loss: 0.67937291
# epoch: 14 -> Accuracy: 99.57%, Loss: 0.03718165 ---------------- Val_Acc: 83.40%, Val_Loss: 0.70037580
# epoch: 15 -> Accuracy: 99.35%, Loss: 0.03770956 ---------------- Val_Acc: 83.60%, Val_Loss: 0.81120390
# --------------------------------------------------

# %%
# Let's plot the results
for idx, el in enumerate(stack):
  print(f"Learning Rate: {learning_rates[idx]}")
  plot_learning_acc_and_loss(*el)
# Out:
# Learning Rate: 1e-05
# Learning Rate: 0.0001
# Learning Rate: 0.001

# %% [markdown]
# # Exercise 2.5: Grid Search
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider different possible combinations of values for each hyper-parameter. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be selected.
#
# In order to perfrom Grid-Search we will use the `GridSearchCV` class from `scikit-learn`, together with some classes from the `skorch` package which allows to use PyTorch models with `scikit-learn`.

# %%
model = NeuralNetClassifier(
    module=FeedforwardNetwork,
    criterion=torch.nn.CrossEntropyLoss,
    optimizer=torch.optim.Adam,
    max_epochs=2)

# we need to adapt PyTorch Dataset to work with Scikit-Learn GridSearchCV
# we use the SliceDataset class from skorch package for this purpose
X_slice = SliceDataset(train_dataset, idx=1)
y_slice = SliceDataset(train_dataset, idx=0)

# %% [markdown]
# ## **[TO COMPLETE]**: Define hyperparameters grid

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use dictionaries of very limited size and hyperparameters, but in a real-world scenario a reasonable amount of possible values should be considered (and there are many other approacehs besisdes Grid-Search).

# %% [markdown]
# `%STARTCODE`

# %%
params = {
    'lr': [1e-4], #[TO COMPLETE]
    'module__input_dim': [1000], #[TO COMPLETE]
    'module__num_classes': [4], #[TO COMPLETE]
    'module__hidden_layers_dim': [[128,64],[64,32,16]] #[TO COMPLETE] 
    }

# %% [markdown]
# `%ENDCODE`

# %% [markdown]
# Now you can use `sklearn`'s `GridSearchCV` to search the hyperparameter space of the `NeuralNetClassifier`:

# %%
n_jobs = multiprocessing.cpu_count()-1
gs = GridSearchCV(model, params, n_jobs=n_jobs)

# %%
outputs = gs.fit(X_slice, y_slice)
# Out:
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3838       0.3337        1.3611  7.2822
#       2        1.3328       0.4200        1.3180  9.0775
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3842       0.3262        1.3580  9.0986
#       2        1.3395       0.4244        1.3191  7.2038
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3761       0.3444        1.3579  7.2287
#       2        1.3306       0.4381        1.3181  9.0737
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3850       0.3256        1.3655  9.1380
#       2        1.3442       0.4106        1.3313  7.2454
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3840       0.2963        1.3658  9.0372
#       2        1.3476       0.3812        1.3366  9.0883
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3853       0.2694        1.3838  7.3102
#       2        1.3818       0.2913        1.3803  8.9624
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3846       0.3075        1.3825  8.9962
#       2        1.3798       0.3369        1.3763  7.3054
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3855       0.2775        1.3834  7.1853
#       2        1.3804       0.3150        1.3786  11.0458
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3864       0.2619        1.3845  8.9923
#       2        1.3824       0.2781        1.3810  7.2728
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3861       0.2844        1.3842  8.4021
#       2        1.3828       0.3319        1.3812  9.1029
#   epoch    train_loss    valid_acc    valid_loss      dur
# -------  ------------  -----------  ------------  -------
#       1        1.3786       0.3405        1.3621  10.8991
#       2        1.3330       0.4235        1.3187  10.2938

# %% [markdown]
# ## **[TO COMPLETE]**: Visualize results
# Print the best hyper-parameters and the performances on the best model on the test set:

# %% [markdown]
# `%STARTCODE`

# %%
print("best score: {:.3f}, best params: {}".format(gs.best_score_, gs.best_params_)) #[TO COMPLETE]
# Out:
# best score: 0.417, best params: {'lr': 0.0001, 'module__hidden_layers_dim': [128, 64], 'module__input_dim': 1000, 'module__num_classes': 4}

# %%
X_test = SliceDataset(test_dataset, idx=1)
y_test = SliceDataset(test_dataset, idx=0)
gs.score(X_test, y_test)
# Out:
# 0.445

# %% [markdown]
# `%ENDCODE`
